# %%
import spacy
from spacy.pipeline import EntityRuler
from spacy.lang.en import English
from spacy.tokens import Doc

from spacy import displacy
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download(['stopwords','wordnet'])

import warnings
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data = pd.read_csv("Updated_Job_req.csv")

# %%
data
# Out:
#                                        job_title                  industry  \
# 0                     Sr. Frontend Web Developer      Software Development
# 1                           Sr. Backend Engineer      Software Development
# 2                             Jr Project Manager      Software Development
# 3                          Finance Accounting AR                    Retail
# 4                               Product Designer                Technology
# ..                                           ...                       ...
# 117                     Microsoft 365 Specialist     Technology Consultant
# 118                  Frontend Engineer (Flutter)     Technology Consultant
# 119                              Project Manager  Jasa TI dan Konsultan IT
# 120  Social Media Specialist / Digital Marketing                Technology
# 121                         Full Stack Developer                Technology
#
#             location       type  minimum_job_year  needed  \
# 0      Jakarta Pusat  Full-time                 4       1
# 1      Jakarta Pusat  Full-time                 4       1
# 2      Jakarta Pusat  Full-time                 1       1
# 3    Jakarta Selatan  Full-time                 1       1
# 4            Bandung  Full-time                 1       1
# ..               ...        ...               ...     ...
# 117    Jakarta Pusat   Contract                 1       2
# 118    Jakarta Pusat   Contract                 1       2
# 119  Jakarta Selatan   Contract                 1       2
# 120    Jakarta Pusat  Full-time                 0       2
# 121    Jakarta Pusat  Full-time                 0       2
#
#                             company_name  \
# 0                   Worlder Team Pte Ltd
# 1                   Worlder Team Pte Ltd
# 2                   Worlder Team Pte Ltd
# 3                PT Aditya Saraana Graha
# 4                     Dicoding Indonesia
# ..                                   ...
# 117  Nomura Research Institute Indonesia
# 118  Nomura Research Institute Indonesia
# 119                    Adiraja Integrasi
# 120              PT VEF Solusi Indonesia
# 121              PT VEF Solusi Indonesia
#
#                                           Requirements
# 0    ideal candidate position minimum 5 year experi...
# 1    ideal candidate position strong technical back...
# 2    successful candidate junior project manager po...
# 3    currently seeking candidate position accountan...
# 4    designer essential understand plan conduct des...
# ..                                                 ...
# 117  ideal candidate must demonstrate proven track ...
# 118  ideal candidate demonstrate strong proficiency...
# 119  applicant posse minimum 2 year experience busi...
# 120  candidate demonstrate proficiency social mediu...
# 121  proficiency python javascript stack mysqlmaria...
#
# [122 rows x 8 columns]

# %%
import spacy

# Load the large English model
nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp(data.Requirements[1])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ideal candidate position strong technical background minimum
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  experience executing software development project fluency
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     english
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
#  oral written must well excellent communication interpersonal skill successful candidate take pride developing highquality efficient software positive attitude willingness learn job proficiency server language
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     golang server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  framework echo backend architecture microservices multidatabases infrastructure aws docker onpremise server db mysql source code management github backend test postman python required meet qualification looking challenging rewarding opportunity encourage apply</div></span>

# %%
# The jobzilla skill dataset is jsonl file containing different skills that can be used to create spaCy entity_ruler.
# The data set contains label and pattern-> diferent words used to descibe skills in various resume.
skill_pattern_path = "skill_patterns.jsonl"

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Add entity_ruler to the pipeline if it's not already present
if "entity_ruler" not in nlp.pipe_names:
    ruler = nlp.add_pipe("entity_ruler", after="ner")
else:
    ruler = nlp.get_pipe("entity_ruler")

# %%
# Load skill patterns into the entity_ruler
ruler.from_disk(skill_pattern_path)

# %%
nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
def get_skills(text):
    doc = nlp(text)
    myset = []
    subset = []
    for ent in doc.ents:
        if ent.label_ == "SKILL":
            subset.append(ent.text)
    myset.append(subset)
    return subset


def unique_skills(x):
    return list(set(x))

# %%
data.head(5)
# Out:
#                     job_title              industry         location  \
# 0  Sr. Frontend Web Developer  Software Development    Jakarta Pusat
# 1        Sr. Backend Engineer  Software Development    Jakarta Pusat
# 2          Jr Project Manager  Software Development    Jakarta Pusat
# 3       Finance Accounting AR                Retail  Jakarta Selatan
# 4            Product Designer            Technology          Bandung
#
#         type  minimum_job_year  needed             company_name  \
# 0  Full-time                 4       1     Worlder Team Pte Ltd
# 1  Full-time                 4       1     Worlder Team Pte Ltd
# 2  Full-time                 1       1     Worlder Team Pte Ltd
# 3  Full-time                 1       1  PT Aditya Saraana Graha
# 4  Full-time                 1       1       Dicoding Indonesia
#
#                                         Requirements
# 0  ideal candidate position minimum 5 year experi...
# 1  ideal candidate position strong technical back...
# 2  successful candidate junior project manager po...
# 3  currently seeking candidate position accountan...
# 4  designer essential understand plan conduct des...

# %%
data["skills"] = data.head(200)["Requirements"].str.lower().apply(get_skills)
data["skills"] = data.head(200)["skills"].apply(unique_skills)
data.head()
# Out:
#                     job_title              industry         location  \
# 0  Sr. Frontend Web Developer  Software Development    Jakarta Pusat
# 1        Sr. Backend Engineer  Software Development    Jakarta Pusat
# 2          Jr Project Manager  Software Development    Jakarta Pusat
# 3       Finance Accounting AR                Retail  Jakarta Selatan
# 4            Product Designer            Technology          Bandung
#
#         type  minimum_job_year  needed             company_name  \
# 0  Full-time                 4       1     Worlder Team Pte Ltd
# 1  Full-time                 4       1     Worlder Team Pte Ltd
# 2  Full-time                 1       1     Worlder Team Pte Ltd
# 3  Full-time                 1       1  PT Aditya Saraana Graha
# 4  Full-time                 1       1       Dicoding Indonesia
#
#                                         Requirements  \
# 0  ideal candidate position minimum 5 year experi...
# 1  ideal candidate position strong technical back...
# 2  successful candidate junior project manager po...
# 3  currently seeking candidate position accountan...
# 4  designer essential understand plan conduct des...
#
#                                               skills
# 0  [cs, github, strong technical background, web ...
# 1  [framework, github, source code management, st...
# 2  [jira, computer science, communication skill, ...
# 3  [diligent, accounting, google, work independen...
# 4             [design, professional, growth mindset]

# %%
doc = nlp(data.Requirements[41])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">looking candidate hold minimum bachelor degree
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     computer science
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  information technology around
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  work experience ideal candidate experience developing application using power apps power automate well creating report dashboard using power bi knowledge
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     programming language
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     php
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     golang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  similar considered advantage</div></span>

# %%
# Create a new DataFrame containing only the 'skills' column
skills_df = pd.DataFrame(data["skills"])

# Export the DataFrame to a new CSV file
skills_df.to_csv("skills.csv", index=False)

# %%
data.skills[50]
# Out:
# ['collaboration',
#  'cs',
#  'google',
#  'html',
#  'google analytics',
#  'communication',
#  'problemsolving',
#  'marketing',
#  'javascript',
#  'multidisciplinary',
#  'data analysis',
#  'seo']

# %% [markdown]
# ### Using re

# %%
import re
def get_experience(text):
    pattern = re.compile(r'(\d+)\s+(?:years?|yrs?)\s+experience')
    matches = pattern.findall(text.lower())
    years = [int(match[0] or match[1] or match[2]) for match in matches]
    return years

# Apply the function to the Requirements column
data["experience"] = data["Requirements"].apply(get_experience)

# %%
data.Requirements[2]
# Out:
# 'successful candidate junior project manager position posse bachelor degree engineering computer science along minimum 1 year experience project management expediting previous experience mobile app development software development industry highly preferred ideal candidate excellent organisational communication skill well ability work well team collaborate multiple stakeholder attention detail ability prioritise task essential role proficiency project management tool software particularly jira required knowledge project management methodology agile waterfall plus additionally holding project management professional pmp certification equivalent would advantageous'

# %%
data.head()
# Out:
#                     job_title              industry         location  \
# 0  Sr. Frontend Web Developer  Software Development    Jakarta Pusat
# 1        Sr. Backend Engineer  Software Development    Jakarta Pusat
# 2          Jr Project Manager  Software Development    Jakarta Pusat
# 3       Finance Accounting AR                Retail  Jakarta Selatan
# 4            Product Designer            Technology          Bandung
#
#         type  minimum_job_year  needed             company_name  \
# 0  Full-time                 4       1     Worlder Team Pte Ltd
# 1  Full-time                 4       1     Worlder Team Pte Ltd
# 2  Full-time                 1       1     Worlder Team Pte Ltd
# 3  Full-time                 1       1  PT Aditya Saraana Graha
# 4  Full-time                 1       1       Dicoding Indonesia
#
#                                         Requirements  \
# 0  ideal candidate position minimum 5 year experi...
# 1  ideal candidate position strong technical back...
# 2  successful candidate junior project manager po...
# 3  currently seeking candidate position accountan...
# 4  designer essential understand plan conduct des...
#
#                                               skills experience
# 0  [cs, github, strong technical background, web ...        [5]
# 1  [framework, github, source code management, st...        [5]
# 2  [jira, computer science, communication skill, ...        [1]
# 3  [diligent, accounting, google, work independen...        [3]
# 4             [design, professional, growth mindset]         []

# %%
data.head()
# Out:
#                     job_title              industry         location  \
# 0  Sr. Frontend Web Developer  Software Development    Jakarta Pusat
# 1        Sr. Backend Engineer  Software Development    Jakarta Pusat
# 2          Jr Project Manager  Software Development    Jakarta Pusat
# 3       Finance Accounting AR                Retail  Jakarta Selatan
# 4            Product Designer            Technology          Bandung
#
#         type  minimum_job_year  needed             company_name  \
# 0  Full-time                 4       1     Worlder Team Pte Ltd
# 1  Full-time                 4       1     Worlder Team Pte Ltd
# 2  Full-time                 1       1     Worlder Team Pte Ltd
# 3  Full-time                 1       1  PT Aditya Saraana Graha
# 4  Full-time                 1       1       Dicoding Indonesia
#
#                                         Requirements  \
# 0  ideal candidate position minimum 5 year experi...
# 1  ideal candidate position strong technical back...
# 2  successful candidate junior project manager po...
# 3  currently seeking candidate position accountan...
# 4  designer essential understand plan conduct des...
#
#                                               skills experience  \
# 0  [cs, github, strong technical background, web ...        [5]
# 1  [framework, github, source code management, st...        [5]
# 2  [jira, computer science, communication skill, ...        [1]
# 3  [diligent, accounting, google, work independen...        [3]
# 4             [design, professional, growth mindset]         []
#
#            education
# 0                 []
# 1                 []
# 2  [bachelor degree]
# 3               [d3]
# 4                 []

# %%
data.education[10]
# Out:
# ['bachelor']

# %%
# Define the required skills (user input)
required_skills = ['data science', 'professional', 'python', 'data analysis']

# Function to calculate the points between the skills and the required skills
def calculate_points(skills, required_skills):
    num_skills = len(skills)
    num_required_skills = len(required_skills)
    
    # Calculate the intersection length
    common_skills = len(set(skills).intersection(required_skills))
    
    # Determine the denominator (bigger length)
    denominator = max(num_skills, num_required_skills)
    
    # Calculate the points
    points = common_skills / denominator if denominator != 0 else 0
    return points

# Apply the function to the skills column
data["points"] = data["skills"].apply(lambda skills: calculate_points(skills, required_skills))

# Display the updated dataframe
print(data.head())
# Out:
#                     job_title              industry         location  \
# 0  Sr. Frontend Web Developer  Software Development    Jakarta Pusat
# 1        Sr. Backend Engineer  Software Development    Jakarta Pusat
# 2          Jr Project Manager  Software Development    Jakarta Pusat
# 3       Finance Accounting AR                Retail  Jakarta Selatan
# 4            Product Designer            Technology          Bandung
#
#         type  minimum_job_year  needed             company_name  \
# 0  Full-time                 4       1     Worlder Team Pte Ltd
# 1  Full-time                 4       1     Worlder Team Pte Ltd
# 2  Full-time                 1       1     Worlder Team Pte Ltd
# 3  Full-time                 1       1  PT Aditya Saraana Graha
# 4  Full-time                 1       1       Dicoding Indonesia
#
#                                         Requirements  \
# 0  ideal candidate position minimum 5 year experi...
# 1  ideal candidate position strong technical back...
# 2  successful candidate junior project manager po...
# 3  currently seeking candidate position accountan...
# 4  designer essential understand plan conduct des...
#
#                                               skills experience  \
# 0  [cs, github, strong technical background, web ...        [5]
# 1  [framework, github, source code management, st...        [5]
# 2  [jira, computer science, communication skill, ...        [1]
# 3  [diligent, accounting, google, work independen...        [3]
# 4             [design, professional, growth mindset]         []
#
#            education    points
# 0                 []  0.000000
# 1                 []  0.058824
# 2  [bachelor degree]  0.090909
# 3               [d3]  0.000000
# 4                 []  0.250000

# %%
data.skills[11]
# Out:
# ['data visualization',
#  'data science',
#  'professional',
#  'python',
#  'data analysis']

# %%
data.points[11]
# Out:
# 0.8
